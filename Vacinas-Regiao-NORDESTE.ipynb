# %%
# Este programa utiliza o Banco de Dados Amostra e faz os calculos das pessoas
# vacinadas na REgiao Nordeste

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


import requests 
import pandas as pd
import time
from datetime import datetime
import csv


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# Leitura do arquivo de Vacinacao completo selecionando alguns
# campos para pesquisa:

df = pd.read_csv("BD_Vacina_Amostra-03-05-2021.csv", sep=";")
usecols = ['vacina_fabricante_nome',
                 'paciente_idade',
                 'paciente_id',
                 'vacina_dataAplicacao',
                 'paciente_endereco_uf',
                 'vacina_descricao_dose']

# %%
# Variavel global para ter o valor real obtido na Amostragem

FATOR_AMOSTRA = 0.001

# %%
# Total  de pessoas vacinadas 
# na Região Nordeste:

# (1) Estado ALAGOAS - AL

df.loc[(df.paciente_endereco_uf == 'AL')]
print("AL =", len(df.loc[(df.paciente_endereco_uf == 'AL')]))

df.loc[(df.paciente_endereco_uf == 'AL')].hist(bins=10)
# Out:
# AL = 640
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (2) Estado BAHIA - BA

df.loc[(df.paciente_endereco_uf == 'BA')]

print("BA =", len(df.loc[(df.paciente_endereco_uf == 'BA')]))
df.loc[(df.paciente_endereco_uf == 'BA')].hist(bins=10)
# Out:
# BA = 3610
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (3) Estado CEARÁ

df.loc[(df.paciente_endereco_uf == 'CE')]
print("CE =", len(df.loc[(df.paciente_endereco_uf == 'CE')]))

df.loc[(df.paciente_endereco_uf == 'CE')].hist(bins=10)
# Out:
# CE = 1641
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (4) Estado MARANHÃO - MA

df.loc[(df.paciente_endereco_uf == 'MA')]
print("MA =", len(df.loc[(df.paciente_endereco_uf == 'MA')]))

df.loc[(df.paciente_endereco_uf == 'MA')].hist(bins=10)
# Out:
# MA = 1311
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (5) Estado da PARAÍBA - PB

df.loc[(df.paciente_endereco_uf == 'PB')]

print("PB =", len(df.loc[(df.paciente_endereco_uf == 'PB')]))

df.loc[(df.paciente_endereco_uf == 'PB')].hist(bins=10)
# Out:
# PB = 968
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (6) Estado PERNAMBUCO - PE

df.loc[(df.paciente_endereco_uf == 'PE')]
print("PE =", len(df.loc[(df.paciente_endereco_uf == 'PE')]))

df.loc[(df.paciente_endereco_uf == 'PE')].hist(bins=10)
# Out:
# PE = 1893
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (7) Estado PIAUÍ

df.loc[(df.paciente_endereco_uf == 'PI')]
print("PI =", len(df.loc[(df.paciente_endereco_uf == 'PI')]))

df.loc[(df.paciente_endereco_uf == 'PI')].hist(bins=10)
# Out:
# PI = 667
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (8) Estado do RIO GRANDE DO NORTE - RN

df.loc[(df.paciente_endereco_uf == 'RN')]
print("RN =", len(df.loc[(df.paciente_endereco_uf == 'RN')]))

df.loc[(df.paciente_endereco_uf == 'RN')].hist(bins=10)
# Out:
# RN = 845
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (9) Estado do SERGIPE ("SE")

Sergipe = df.loc[(df.paciente_endereco_uf == 'SE')]

print("SE =", len(df.loc[(df.paciente_endereco_uf == 'SE')]))


df.loc[(df.paciente_endereco_uf == 'SE')].hist(bins=10)
# Out:
# SE = 500
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# Calculando a porcentagem REAL total de vacinados da Região Nordeste
#


Porcentagem = len(df.loc[df['paciente_endereco_uf']
            .isin(['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE' ])])

print("Somando total de vacinados .......", Porcentagem)

Porcentagem = Porcentagem/(211755692)
                                

print('A porcentagem REAL brasileiros vacinadas na Regiao Nordeste é: ', Porcentagem/FATOR_AMOSTRA)
# Out:
# Somando total de vacinados ....... 12075
# A porcentagem REAL brasileiros vacinadas na Regiao Nordeste é:  0.05702326056009866
