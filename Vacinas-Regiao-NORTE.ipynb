# %%
# Este programa utiliza a base de dados da Amostra e faz os calculos dos Estados da Regiao
# Nordeste que foram vacinados

# %%
import requests 
import pandas as pd
import time
from datetime import datetime
import csv


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# Leitura do arquivo de Vacinacao completo selecionando alguns
# campos para pesquisa:

df = pd.read_csv("BD_Vacina_Amostra-03-05-2021.csv", sep=";")
usecols = ['vacina_fabricante_nome',
                 'paciente_idade',
                 'paciente_id',
                 'vacina_dataAplicacao',
                 'paciente_endereco_uf',
                 'vacina_descricao_dose']

# %%
FATOR_AMOSTRA = 0.001

# %%
# Total  de pessoas vacinadas 
# na Região Norte:
print("Fazendo a leitura do arquivo...")



# (1) Estado AMAZONAS - AM


Amazonas = df.loc[(df.paciente_endereco_uf == 'AM')]

print(len(Amazonas))


Amazonas.hist(bins=10)
# Out:
# Fazendo a leitura do arquivo...
# 764
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (2) Estado do PARÁ - PA


Para= df.loc[(df.paciente_endereco_uf == 'PA') ]

print(len(Para))

Para.hist(bins=10)
# Out:
# 1297
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (3) Estado do ACRE - AC


Acre = df.loc[(df.paciente_endereco_uf == 'AC')] 

print(len(Acre))

Acre.hist(bins=10)
# Out:
# 140
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (4) Estado do RONDÔNIA - RO


Rondonia = df.loc[(df.paciente_endereco_uf == 'RO')]
print(len(Rondonia))

Rondonia.hist(bins=10)
# Out:
# 259
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (5) Estado de Roraima - RR

Roraima = df.loc[(df.paciente_endereco_uf == 'RR')]
print(len(Roraima))

Roraima.hist(bins=10)
# Out:
# 115
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (6) Estado do AMAPÁ - AP



Amapa = df.loc[(df.paciente_endereco_uf == 'AP') ]
print(len(Amapa))

Amapa.hist(bins=10)
# Out:
# 121
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (7) Estado de TOCANTINS - TO


Tocantins = df.loc[(df.paciente_endereco_uf == 'TO') ]
print(len(Tocantins))
       
Tocantins.hist(bins=10)
# Out:
# 278
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# Calculando o total de vacinados da Região Norte
#
Porcentagem = df.loc[df['paciente_endereco_uf']
                    .isin(['AM', 'PA', 'AC', 'RO', 'RR', 'AP', 'TO'])]

Porcentagem.hist(bins=10)


print ("Somando total de vacinados .......", Porcentagem)

Porcentagem = len(Porcentagem)/211755692                                      
                     

print("A soma total da Regiao Norte --------> ", Porcentagem/FATOR_AMOSTRA)
# Out:
# Somando total de vacinados .......       vacina_fabricante_nome  paciente_idade  \
# 2      FUNDACAO OSWALDO CRUZ              50
# 526        FUNDACAO BUTANTAN              91
# 585        FUNDACAO BUTANTAN              86
# 610        FUNDACAO BUTANTAN              70
# 614        FUNDACAO BUTANTAN              70
# ...                      ...             ...
# 46744      FUNDACAO BUTANTAN              69
# 46763      FUNDACAO BUTANTAN              84
# 46769      FUNDACAO BUTANTAN              28
# 46775      FUNDACAO BUTANTAN              37
# 46777      FUNDACAO BUTANTAN              29
#
#                                              paciente_id  \
# 2      5c7b5eff22619003b73802017d3a554249cb0547f19d13...
# 526    124e98d2be53bb34bf5548ec50aa4e7ca2f9e6b73faebe...
# 585    df53cf8f6b9bb101cd538d8509115dba3bdef1e3e8adbd...
# 610    c28637bdf4c20cdc388eb858f5d020a18a9cf0aaf4e9f2...
# 614    6ba62b2f7f0d8051ed879a160e5892ab6b9a59cb0b114b...
# ...
