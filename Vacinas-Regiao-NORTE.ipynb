# %%
import requests 
import pandas as pd
import time
from datetime import datetime
import csv


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# Leitura do arquivo de Vacinacao completo selecionando alguns
# campos para pesquisa:

df = pd.read_csv("vacinas_2021-04-03-1708.csv", sep=";", 
                 usecols=['vacina_descricao_dose', 'paciente_idade',
                          'vacina_categoria_nome',
                          'vacina_fabricante_nome', 'paciente_endereco_uf'])

# %%
# Total  de pessoas vacinadas 
# na Região Norte:
print("Fazendo a leitura do arquivo...")



# (1) Estado AMAZONAS - AM


Amazonas = df.loc[(df.paciente_endereco_uf == 'AM')]

print(len(Amazonas))


Amazonas.hist(bins=100)
# Out:
# Fazendo a leitura do arquivo...
# 460489
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (2) Estado do PARÁ - PA


Para= df.loc[(df.paciente_endereco_uf == 'PA') ]

print(len(Para))

Para.hist(bins=100)
# Out:
# 577006
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (3) Estado do ACRE - AC


Acre = df.loc[(df.paciente_endereco_uf == 'AC')] 

print(len(Acre))

Acre.hist(bins=100)
# Out:
# 65612
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (4) Estado do RONDÔNIA - RO


Rondonia = df.loc[(df.paciente_endereco_uf == 'RO')]
print(len(Rondonia))

Rondonia.hist(bins=100)
# Out:
# 126029
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (5) Estado de Roraima - RR

Roraima = df.loc[(df.paciente_endereco_uf == 'RR')]
print(len(Roraima))

Roraima.hist(bins=100)
# Out:
# 63372
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (6) Estado do AMAPÁ - AP



Amapa = df.loc[(df.paciente_endereco_uf == 'AP') ]
print(len(Amapa))

Amapa.hist(bins=100)
# Out:
# 64573
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# (7) Estado de TOCANTINS - TO


Tocantins = df.loc[(df.paciente_endereco_uf == 'TO') ]
print(len(Tocantins))
       
Tocantins.hist(bins=100)
# Out:
# 140366
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %%
# Calculando o total de vacinados da Região Norte
#


print ("Somando total de vacinados .......")


soma_1 = df.loc[df['paciente_endereco_uf'].isin(['AM', 'PA', 'AC', 'RO', 'RR', 'AP', 'TO'])]


print("A soma total da Regiao Norte --------> ", len(soma_1))
# Out:
# Somando total de vacinados .......
# A soma total da Regiao Norte -------->  1497447

# %%
Porcentagem = len(soma_1)/(212000)

print('A porcentagem brasileiros vacinadas na Regiao SUL é: ', Porcentagem)
# Out:
# A porcentagem brasileiros vacinadas na Regiao SUL é:  7.063429245283019

# %%
soma_1.hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)
