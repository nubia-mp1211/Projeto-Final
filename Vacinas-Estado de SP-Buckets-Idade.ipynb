# %%
import requests 
import pandas as pd
import time
from datetime import datetime
import csv

# Importar bibliotecas para construir gráficos:

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# Leitura do arquivo de Vacinacao completo selecionando alguns
# campos para pesquisa:

df = pd.read_csv("vacinas_2021-04-10-1357.csv", sep=";", 
                 usecols = ['vacina_fabricante_nome',
                            'paciente_idade',
                            'vacina_dataAplicacao',
                            'paciente_endereco_uf',
                            'vacina_descricao_dose'])

# %%
# Tamanho do Arquivo atualizado, com o Programa: "Alguns-Campos-Rodar-Esse")

df.shape
# Out:
# (26434681, 5)

# %% [markdown]
# # Vacinados no Estado de SP

# %%
df['paciente_endereco_uf'].describe
# Out:
# <bound method NDFrame.describe of 0           AM
# 1           SP
# 2           SP
# 3           SP
# 4           RJ
#             ..
# 26434676    MG
# 26434677    SP
# 26434678    SP
# 26434679    SP
# 26434680    PA
# Name: paciente_endereco_uf, Length: 26434681, dtype: object>

# %% [markdown]
# # Total  de pessoas vacinadas
# # no Estado de SP

# %%
#Selecionando o campo cujo endereço de São Paulo - SP

df.loc[df['paciente_endereco_uf'] == 'SP'].hist(bins=20)

# População do Estado de São Paulo (SP) de acordo com CNN Brasil:46.289.333

print('Total de vacinados em São Paulo - SP ==>', len(df.loc[df.paciente_endereco_uf == 'SP']))

print('Porcentagem dos Vacinados em SP:     ==>',
      len(df.loc[df.paciente_endereco_uf == 'SP'])/46289333)



Vacinados_sp = len(Sao_Paulo)/(46289333)
# Out:
# Total de vacinados em São Paulo - SP ==> 6786153
# Porcentagem dos Vacinados em SP:     ==> 0.14660295493996425

# %% [markdown]
# # Pesquisando por Faixa Etária: > = 100 Anos

# %%
# Pesquisando dados por faixa etária >= 100anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 100))]

df.loc[(df.paciente_endereco_uf == 'SP') & ((df.paciente_idade < 100) )].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando o número de pessoas vacinadas entre 90 - 100 Anos

# %%
# Selecionando as pessoas vacinadas em SP entre 90 e 100anos:

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 100) & (df.paciente_idade >= 90))]

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 100) & (df.paciente_idade >= 90))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando número de pessoas vacinadas entre 80 - 90 Anos

# %%
# Selecionando as pessoas vacinadas em  SP faixa etaria >80
# e menor que 90 anos
    

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 90) & (df.paciente_idade >= 80))]

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 90) & (df.paciente_idade >= 80))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando Pessoas entre 70 - 80 Anos

# %%
# Selecionando as pessoas vacinadas em SP e maiores ou igual de 70 anos
# e menor que 80 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 80) & (df.paciente_idade >=70))]

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 80) & (df.paciente_idade >=70))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando pessoas entre 60 - 70 Anos

# %%
# Selecionando os vacinados que são maiores = 60 e menor que 70 anos:


df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 70) & (df.paciente_idade >=60))]



df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 70) & (df.paciente_idade >=60))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando pessoas entre 50 - 60 Anos

# %%
# Selecionando as pessoas vacinadas em SP e menor 60 anos
# e maior ou igual a 50 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 60) & (df.paciente_idade >=50))]


df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 60) & (df.paciente_idade >=50))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando pessoas entre 40 - 50 Anos

# %%
# Selecionando as pessoas vacinadas em SP e menor 50 anos
# e maior ou igual a 40 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 50) & (df.paciente_idade >=40))]


df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 50) & (df.paciente_idade >=40))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # pesquisando Pessoas entre 30 - 40 Anos

# %%
# Selecionando as pessoas vacinadas em SP maior que 50 e menor 
# 40 anos


df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 40) & (df.paciente_idade >=30))]



df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 40) & (df.paciente_idade >=30))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando pessoas com idades entre 20-30 Anos

# %%
# Selecionando as pessoas vacinadas em SP e menor 30 anos
# e maior ou igual a 20 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 30) & (df.paciente_idade >=20))]

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 30) & (df.paciente_idade >=20))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
# # Pesquisando Pessoas na faixa etária de 10 - 20 anos

# %%
# Selecionando as pessoas vacinadas em SP e menor 20 anos
# e maior ou igual a 10 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 20) & (df.paciente_idade >= 10))]

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 20) & (df.paciente_idade >= 10))].hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'paciente_idade'}>]], dtype=object)

# %% [markdown]
#  # Pesquisando pessoas entre 0 - 10 Anos

# %%
# Selecionando as pessoas vacinadas em SP e menor 10 anos
# e maior ou igual a 0 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 10) & (df.paciente_idade >= 0))]
# Out:
#          vacina_fabricante_nome  paciente_idade      vacina_dataAplicacao  \
# 89611        AstraZeneca/Oxford             5.0  2021-01-27T00:00:00.000Z
# 433418                  Sinovac             2.0  2021-03-04T00:00:00.000Z
# 587382        FUNDACAO BUTANTAN             6.0  2021-02-12T03:00:00.000Z
# 636555                  Sinovac             8.0  2021-03-01T00:00:00.000Z
# 654300                  Sinovac             0.0  2021-01-23T00:00:00.000Z
# ...                         ...             ...                       ...
# 25777319                Sinovac             9.0  2021-02-08T00:00:00.000Z
# 25921120     AstraZeneca/Oxford             8.0  2021-02-04T00:00:00.000Z
# 26286103                Sinovac             7.0  2021-01-22T00:00:00.000Z
# 26335583     AstraZeneca/Oxford             8.0  2021-02-05T00:00:00.000Z
# 26357188      FUNDACAO BUTANTAN             9.0  2021-02-24T03:00:00.000Z
#
#          paciente_endereco_uf vacina_descricao_dose
# 89611                      SP               1ª Dose
# 433418                     SP               2ª Dose
# 587382                     SP               2ª Dose
# 636555                     SP               1ª Dose
# 654300                     SP               1ª Dose
# ...                       ...                   ...
# 25777319                   SP               1ª Dose
# 25921120                   SP               1ª Dose
# 26286103                   SP               1ª Dose
# 26335583                   SP               1ª Dose
# 26357188                   SP               1ª Dose
#
# [180 rows x 5 columns]

# %% [markdown]
# # Desmembrando por idade 19 - 20 Anos

# %%
# Selecionando as pessoas vacinadas em SP e menor 9 anos
# e maior ou igual a 8 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 20) & (df.paciente_idade >=19))]
# Out:
#                 vacina_fabricante_nome  paciente_idade  \
# 159                 AstraZeneca/Oxford            19.0
# 324                 AstraZeneca/Oxford            19.0
# 2713      SERUM INSTITUTE OF INDIA LTD            19.0
# 4503       SINOVAC LIFE SCIENCE CO LTD            19.0
# 4543      SERUM INSTITUTE OF INDIA LTD            19.0
# ...                                ...             ...
# 26429432                       Sinovac            19.0
# 26429650            AstraZeneca/Oxford            19.0
# 26430780                       Sinovac            19.0
# 26430872                       Sinovac            19.0
# 26434551            AstraZeneca/Oxford            19.0
#
#               vacina_dataAplicacao paciente_endereco_uf vacina_descricao_dose
# 159       2021-02-04T00:00:00.000Z                   SP               1ª Dose
# 324       2021-02-04T00:00:00.000Z                   SP               1ª Dose
# 2713      2021-02-04T00:00:00.000Z                   SP               1ª Dose
# 4503      2021-02-02T00:00:00.000Z                   SP               1ª Dose
# 4543      2021-02-09T00:00:00.000Z                   SP               1ª Dose
# ...                            ...                  ...                   ...
# 26429432  2021-01-29T00:00:00.000Z                   SP               1ª Dose
# 26429650  2021-01-28T00:00:00.000Z                   SP               1ª Dose
# 26430780  2021-02-04T00:00:00.000Z                   SP               1ª Dose
# 26430872  2021-02-03T00:00:00.000Z                   SP               1ª Dose
# 26434551  2021-02-03T00:00:00.000Z                   SP               1ª Dose
#
# [15916 rows x 5 columns]

# %%
# Selecionando as pessoas vacinadas em SP e menor 19 anos
# e maior ou igual a 18 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 19) & (df.paciente_idade >=18))]
# Out:
#                 vacina_fabricante_nome  paciente_idade  \
# 1451      SERUM INSTITUTE OF INDIA LTD            18.0
# 1508      SERUM INSTITUTE OF INDIA LTD            18.0
# 3928       SINOVAC LIFE SCIENCE CO LTD            18.0
# 4213       SINOVAC LIFE SCIENCE CO LTD            18.0
# 5697      SERUM INSTITUTE OF INDIA LTD            18.0
# ...                                ...             ...
# 26428729                       Sinovac            18.0
# 26432042                       Sinovac            18.0
# 26433434                       Sinovac            18.0
# 26434416            AstraZeneca/Oxford            18.0
# 26434581                       Sinovac            18.0
#
#               vacina_dataAplicacao paciente_endereco_uf vacina_descricao_dose
# 1451      2021-02-10T00:00:00.000Z                   SP               2ª Dose
# 1508      2021-02-05T00:00:00.000Z                   SP               1ª Dose
# 3928      2021-02-05T00:00:00.000Z                   SP               1ª Dose
# 4213      2021-01-25T00:00:00.000Z                   SP               1ª Dose
# 5697      2021-02-03T00:00:00.000Z                   SP               1ª Dose
# ...                            ...                  ...                   ...
# 26428729  2021-02-13T00:00:00.000Z                   SP               1ª Dose
# 26432042  2021-03-03T00:00:00.000Z                   SP               2ª Dose
# 26433434  2021-02-24T00:00:00.000Z                   SP               1ª Dose
# 26434416  2021-02-03T00:00:00.000Z                   SP               1ª Dose
# 26434581  2021-02-05T00:00:00.000Z                   SP               1ª Dose
#
# [8553 rows x 5 columns]

# %%
# Selecionando as pessoas vacinadas em SP e menor 18 anos
# e maior ou igual a 17 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 18) & (df.paciente_idade >= 17))]
# Out:
#                 vacina_fabricante_nome  paciente_idade  \
# 36088     SERUM INSTITUTE OF INDIA LTD            17.0
# 64339     SERUM INSTITUTE OF INDIA LTD            17.0
# 69170      SINOVAC LIFE SCIENCE CO LTD            17.0
# 100511                         Sinovac            17.0
# 120601              AstraZeneca/Oxford            17.0
# ...                                ...             ...
# 26399653                       Sinovac            17.0
# 26413049                       Sinovac            17.0
# 26417304            AstraZeneca/Oxford            17.0
# 26419721                       Sinovac            17.0
# 26430728                       Sinovac            17.0
#
#               vacina_dataAplicacao paciente_endereco_uf vacina_descricao_dose
# 36088     2021-02-08T00:00:00.000Z                   SP               1ª Dose
# 64339     2021-02-12T00:00:00.000Z                   SP               2ª Dose
# 69170     2021-02-05T00:00:00.000Z                   SP               1ª Dose
# 100511    2021-02-15T00:00:00.000Z                   SP               1ª Dose
# 120601    2021-01-29T00:00:00.000Z                   SP               1ª Dose
# ...                            ...                  ...                   ...
# 26399653  2021-02-17T00:00:00.000Z                   SP               2ª Dose
# 26413049  2021-02-22T00:00:00.000Z                   SP               1ª Dose
# 26417304  2021-01-29T00:00:00.000Z                   SP               1ª Dose
# 26419721  2021-02-02T00:00:00.000Z                   SP               1ª Dose
# 26430728  2021-02-19T00:00:00.000Z                   SP               2ª Dose
#
# [794 rows x 5 columns]

# %%
# Selecionando as pessoas vacinadas em SP e menor 17 anos
# e maior ou igual a 16 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 17) & (df.paciente_idade >= 16))]
# Out:
#                 vacina_fabricante_nome  paciente_idade  \
# 1437      SERUM INSTITUTE OF INDIA LTD            16.0
# 118870                         Sinovac            16.0
# 120835              AstraZeneca/Oxford            16.0
# 221344                         Sinovac            16.0
# 267861              AstraZeneca/Oxford            16.0
# ...                                ...             ...
# 25360008                       SINOVAC            16.0
# 25731954            AstraZeneca/Oxford            16.0
# 25789060            AstraZeneca/Oxford            16.0
# 25924760            AstraZeneca/Oxford            16.0
# 26080639                       Sinovac            16.0
#
#               vacina_dataAplicacao paciente_endereco_uf vacina_descricao_dose
# 1437      2021-02-03T00:00:00.000Z                   SP               1ª Dose
# 118870    2021-01-25T00:00:00.000Z                   SP               1ª Dose
# 120835    2021-02-04T00:00:00.000Z                   SP               1ª Dose
# 221344    2021-03-03T00:00:00.000Z                   SP               2ª Dose
# 267861    2021-02-06T00:00:00.000Z                   SP               1ª Dose
# ...                            ...                  ...                   ...
# 25360008  2021-03-26T00:00:00.000Z                   SP               1ª Dose
# 25731954  2021-02-01T00:00:00.000Z                   SP               1ª Dose
# 25789060  2021-01-29T00:00:00.000Z                   SP               1ª Dose
# 25924760  2021-01-29T00:00:00.000Z                   SP               1ª Dose
# 26080639  2021-02-10T00:00:00.000Z                   SP               1ª Dose
#
# [233 rows x 5 columns]

# %%
# Selecionando as pessoas vacinadas em SP e menor 16 anos
# e maior ou igual a 15 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 16) & (df.paciente_idade >= 15))]
# Out:
#          vacina_fabricante_nome  paciente_idade      vacina_dataAplicacao  \
# 316057                  Sinovac            15.0  2021-02-10T00:00:00.000Z
# 329838                  Sinovac            15.0  2021-02-23T00:00:00.000Z
# 409647                  Sinovac            15.0  2021-01-29T00:00:00.000Z
# 482509                  Sinovac            15.0  2021-02-18T00:00:00.000Z
# 815727                  Sinovac            15.0  2021-03-03T00:00:00.000Z
# ...                         ...             ...                       ...
# 23104617     AstraZeneca/Oxford            15.0  2021-03-02T00:00:00.000Z
# 23533545                Sinovac            15.0  2021-03-24T00:00:00.000Z
# 25107546                Sinovac            15.0  2021-03-16T00:00:00.000Z
# 25357049                Sinovac            15.0  2021-03-11T00:00:00.000Z
# 26117923                Sinovac            15.0  2021-02-10T00:00:00.000Z
#
#          paciente_endereco_uf vacina_descricao_dose
# 316057                     SP               1ª Dose
# 329838                     SP               1ª Dose
# 409647                     SP               1ª Dose
# 482509                     SP               2ª Dose
# 815727                     SP               2ª Dose
# ...                       ...                   ...
# 23104617                   SP               1ª Dose
# 23533545                   SP               1ª Dose
# 25107546                   SP               2ª Dose
# 25357049                   SP               2ª Dose
# 26117923                   SP               1ª Dose
#
# [68 rows x 5 columns]

# %%
# Selecionando as pessoas vacinadas em SP e menor 15 anos
# e maior ou igual a 14 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 15) & (df.paciente_idade >= 14))]
# Out:
#                 vacina_fabricante_nome  paciente_idade  \
# 140839              AstraZeneca/Oxford            14.0
# 1136910                        Sinovac            14.0
# 2243502                        Sinovac            14.0
# 3376291                        Sinovac            14.0
# 3882209                        Sinovac            14.0
# 4106567               SINOVAC/BUTANTAN            14.0
# 4756024                        Sinovac            14.0
# 4970609                        Sinovac            14.0
# 5206382                        Sinovac            14.0
# 6755504                        SINOVAC            14.0
# 7183513                        Sinovac            14.0
# 8788631             AstraZeneca/Oxford            14.0
# 8899660                        Sinovac            14.0
# 9006928                        Sinovac            14.0
# 9041766             AstraZeneca/Oxford            14.0
# 9268673                        Sinovac            14.0
# 9294584                        Sinovac            14.0
# 9516599             AstraZeneca/Oxford            14.0
# 9807681             AstraZeneca/Oxford            14.0
# 10495620                       Sinovac            14.0
# 10585436            AstraZeneca/Oxford            14.0
# 12644044                       Sinovac            14.0
# 12998976                       Sinovac            14.0
# 14132012                       SINOVAC            14.0
# 14592248  BUTANTAN - FUNDACAO BUTANTAN            14.0
# 15168862                       Sinovac            14.0
# 15171729                       Sinovac            14.0
# 16060183             FUNDACAO BUTANTAN            14.0
# 17148197                       Sinovac            14.0
# 17558148            AstraZeneca/Oxford            14.0
# 17708081            AstraZeneca/Oxford            14.0
# 17775393                       Sinovac            14.0
# 17970743                       Sinovac            14.0
# 19081325                       Sinovac            14.0
# 19908476                       Sinovac            14.0
# 20518940                       Sinovac            14.0
# 20573195         FUNDACAO OSWALDO CRUZ            14.0
# 21871509   SINOVAC LIFE SCIENCE CO LTD            14.0
# 22523349  SERUM INSTITUTE OF INDIA LTD            14.0
# 23046555                       Sinovac            14.0
# 25043454                       SINOVAC            14.0
# 26251991                       Sinovac            14.0
#
#               vacina_dataAplicacao paciente_endereco_uf vacina_descricao_dose
# 140839    2021-03-02T00:00:00.000Z                   SP               1ª Dose
# 1136910   2021-02-15T00:00:00.000Z                   SP               1ª Dose
# 2243502   2021-02-15T00:00:00.000Z                   SP               2ª Dose
# 3376291   2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 3882209   2021-03-06T00:00:00.000Z                   SP               2ª Dose
# 4106567   2021-04-08T00:00:00.000Z                   SP               2ª Dose
# 4756024   2021-02-16T00:00:00.000Z                   SP               2ª Dose
# 4970609   2021-02-19T00:00:00.000Z                   SP               2ª Dose
# 5206382   2021-01-28T00:00:00.000Z                   SP               1ª Dose
# 6755504   2021-03-30T00:00:00.000Z                   SP               1ª Dose
# 7183513   2021-03-09T00:00:00.000Z                   SP               1ª Dose
# 8788631   2021-03-01T00:00:00.000Z                   SP               1ª Dose
# 8899660   2021-02-19T00:00:00.000Z                   SP               2ª Dose
# 9006928   2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 9041766   2021-01-28T00:00:00.000Z                   SP               1ª Dose
# 9268673   2021-02-15T00:00:00.000Z                   SP               1ª Dose
# 9294584   2021-03-06T00:00:00.000Z                   SP               1ª Dose
# 9516599   2021-01-30T00:00:00.000Z                   SP               1ª Dose
# 9807681   2021-02-03T00:00:00.000Z                   SP               1ª Dose
# 10495620  2021-01-23T00:00:00.000Z                   SP               1ª Dose
# 10585436  2021-03-01T00:00:00.000Z                   SP               1ª Dose
# 12644044  2021-03-16T00:00:00.000Z                   SP               2ª Dose
# 12998976  2021-03-17T00:00:00.000Z                   SP               1ª Dose
# 14132012  2021-04-07T00:00:00.000Z                   SP               1ª Dose
# 14592248  2021-03-13T00:00:00.000Z                   SP               1ª Dose
# 15168862  2021-03-08T00:00:00.000Z                   SP               2ª Dose
# 15171729  2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 16060183  2021-03-26T00:00:00.000Z                   SP               1ª Dose
# 17148197  2021-02-12T00:00:00.000Z                   SP               2ª Dose
# 17558148  2021-03-02T00:00:00.000Z                   SP               1ª Dose
# 17708081  2021-03-01T00:00:00.000Z                   SP               1ª Dose
# 17775393  2021-02-19T00:00:00.000Z                   SP               1ª Dose
# 17970743  2021-03-04T00:00:00.000Z                   SP               1ª Dose
# 19081325  2021-02-12T00:00:00.000Z                   SP               1ª Dose
# 19908476  2021-02-11T00:00:00.000Z                   SP               2ª Dose
# 20518940  2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 20573195  2021-02-05T03:00:00.000Z                   SP               1ª Dose
# 21871509  2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 22523349  2021-02-15T00:00:00.000Z                   SP               2ª Dose
# 23046555  2021-03-23T00:00:00.000Z                   SP               1ª Dose
# 25043454  2021-03-25T00:00:00.000Z                   SP               1ª Dose
# 26251991  2021-02-19T00:00:00.000Z                   SP               2ª Dose

# %%
# Selecionando as pessoas vacinadas em SP e menor 14 anos
# e maior ou igual a 13 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 14) & (df.paciente_idade >= 13))]
# Out:
#                 vacina_fabricante_nome  paciente_idade  \
# 225713                         Sinovac            13.0
# 467346                         Sinovac            13.0
# 850210                         Sinovac            13.0
# 1367503                        Sinovac            13.0
# 2007141                        Sinovac            13.0
# 2195147                        Sinovac            13.0
# 3991805                        SINOVAC            13.0
# 4375988                        SINOVAC            13.0
# 4934370             AstraZeneca/Oxford            13.0
# 7943458   SERUM INSTITUTE OF INDIA LTD            13.0
# 9489843             AstraZeneca/Oxford            13.0
# 10059841                       Sinovac            13.0
# 10181097            AstraZeneca/Oxford            13.0
# 11653455                       Sinovac            13.0
# 13001577                       Sinovac            13.0
# 13353737                       SINOVAC            13.0
# 13475098                       SINOVAC            13.0
# 13565022            AstraZeneca/Oxford            13.0
# 13773291                       SINOVAC            13.0
# 15176283            AstraZeneca/Oxford            13.0
# 17798650                       Sinovac            13.0
# 18115650                       Sinovac            13.0
# 19587707                       Sinovac            13.0
# 19920845            AstraZeneca/Oxford            13.0
# 20609801                       Sinovac            13.0
# 22210983            AstraZeneca/Oxford            13.0
# 22500927                       Sinovac            13.0
# 23115755             FUNDACAO BUTANTAN            13.0
# 24299108                       SINOVAC            13.0
#
#               vacina_dataAplicacao paciente_endereco_uf vacina_descricao_dose
# 225713    2021-03-03T00:00:00.000Z                   SP               2ª Dose
# 467346    2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 850210    2021-02-17T00:00:00.000Z                   SP               2ª Dose
# 1367503   2021-02-20T00:00:00.000Z                   SP               2ª Dose
# 2007141   2021-01-22T00:00:00.000Z                   SP               1ª Dose
# 2195147   2021-03-19T00:00:00.000Z                   SP               1ª Dose
# 3991805   2021-04-05T00:00:00.000Z                   SP               1ª Dose
# 4375988   2021-03-22T00:00:00.000Z                   SP               1ª Dose
# 4934370   2021-03-01T00:00:00.000Z                   SP               1ª Dose
# 7943458   2021-03-17T00:00:00.000Z                   SP               1ª Dose
# 9489843   2021-02-06T00:00:00.000Z                   SP               1ª Dose
# 10059841  2021-03-08T00:00:00.000Z                   SP               1ª Dose
# 10181097  2021-01-27T00:00:00.000Z                   SP               1ª Dose
# 11653455  2021-03-04T00:00:00.000Z                   SP               1ª Dose
# 13001577  2021-03-19T00:00:00.000Z                   SP               1ª Dose
# 13353737  2021-04-08T00:00:00.000Z                   SP               2ª Dose
# 13475098  2021-04-05T00:00:00.000Z                   SP               1ª Dose
# 13565022  2021-03-08T00:00:00.000Z                   SP               1ª Dose
# 13773291  2021-03-19T00:00:00.000Z                   SP               1ª Dose
# 15176283  2021-02-05T00:00:00.000Z                   SP               1ª Dose
# 17798650  2021-02-10T00:00:00.000Z                   SP               1ª Dose
# 18115650  2021-03-02T00:00:00.000Z                   SP               2ª Dose
# 19587707  2021-03-03T00:00:00.000Z                   SP               2ª Dose
# 19920845  2021-01-27T00:00:00.000Z                   SP               1ª Dose
# 20609801  2021-02-03T00:00:00.000Z                   SP               1ª Dose
# 22210983  2021-02-15T00:00:00.000Z                   SP               1ª Dose
# 22500927  2021-01-30T00:00:00.000Z                   SP               1ª Dose
# 23115755  2021-02-24T03:00:00.000Z                   SP               2ª Dose
# 24299108  2021-03-24T00:00:00.000Z                   SP               1ª Dose

# %%
# Selecionando as pessoas vacinadas em SP e menor 13 anos
# e maior ou igual a 12 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 13) & (df.paciente_idade >= 12))]
# Out:
#          vacina_fabricante_nome  paciente_idade      vacina_dataAplicacao  \
# 375590                  Sinovac            12.0  2021-02-05T00:00:00.000Z
# 598544       AstraZeneca/Oxford            12.0  2021-03-03T00:00:00.000Z
# 723809                  Sinovac            12.0  2021-02-17T00:00:00.000Z
# 2001375                 Sinovac            12.0  2021-01-21T00:00:00.000Z
# 2308352                 Sinovac            12.0  2021-02-11T00:00:00.000Z
# 2727268                 SINOVAC            12.0  2021-03-29T00:00:00.000Z
# 2747590                 SINOVAC            12.0  2021-04-05T00:00:00.000Z
# 3243688                 Sinovac            12.0  2021-03-16T00:00:00.000Z
# 3731424                 SINOVAC            12.0  2021-04-05T00:00:00.000Z
# 6948915                 SINOVAC            12.0  2021-03-29T00:00:00.000Z
# 8264272                 Sinovac            12.0  2021-01-20T00:00:00.000Z
# 9260187                 Sinovac            12.0  2021-02-17T00:00:00.000Z
# 9856087                 Sinovac            12.0  2021-03-04T00:00:00.000Z
# 10122103     AstraZeneca/Oxford            12.0  2021-03-01T00:00:00.000Z
# 10852497                Sinovac            12.0  2021-01-29T00:00:00.000Z
# 11989061                Sinovac            12.0  2021-03-08T00:00:00.000Z
# 13333545                SINOVAC            12.0  2021-04-05T00:00:00.000Z
# 13794105                SINOVAC            12.0  2021-04-05T00:00:00.000Z
# 15128965                Sinovac            12.0  2021-02-05T00:00:00.000Z
# 16915569                SINOVAC            12.0  2021-04-02T00:00:00.000Z
# 17200214                Sinovac            12.0  2021-02-13T00:00:00.000Z
# 18211552                Sinovac            12.0  2021-02-24T00:00:00.000Z
# 18771590                Sinovac            12.0  2021-03-19T00:00:00.000Z
# 19016786     AstraZeneca/Oxford            12.0  2021-02-01T00:00:00.000Z
# 19671446                Sinovac            12.0  2021-02-26T00:00:00.000Z
# 21600858                Sinovac            12.0  2021-03-06T00:00:00.000Z
# 21659831                Sinovac            12.0  2021-02-02T00:00:00.000Z
# 24824045                Sinovac            12.0  2021-03-12T00:00:00.000Z
# 25964381                Sinovac            12.0  2021-02-20T00:00:00.000Z
# 26133727                Sinovac            12.0  2021-03-05T00:00:00.000Z
#
#          paciente_endereco_uf vacina_descricao_dose
# 375590                     SP               1ª Dose
# 598544                     SP               1ª Dose
# 723809                     SP               2ª Dose
# 2001375                    SP               1ª Dose
# 2308352                    SP               1ª Dose
# 2727268                    SP               1ª Dose
# 2747590                    SP               1ª Dose
# 3243688                    SP               1ª Dose
# 3731424                    SP               1ª Dose
# 6948915                    SP               2ª Dose
# 8264272                    SP               1ª Dose
# 9260187                    SP               2ª Dose
# 9856087                    SP               2ª Dose
# 10122103                   SP               1ª Dose
# 10852497                   SP               1ª Dose
# 11989061                   SP               1ª Dose
# 13333545                   SP               1ª Dose
# 13794105                   SP               2ª Dose
# 15128965                   SP               1ª Dose
# 16915569                   SP               1ª Dose
# 17200214                   SP               1ª Dose
# 18211552                   SP               2ª Dose
# 18771590                   SP               1ª Dose
# 19016786                   SP               1ª Dose
# 19671446                   SP               2ª Dose
# 21600858                   SP               2ª Dose
# 21659831                   SP               1ª Dose
# 24824045                   SP               2ª Dose
# 25964381                   SP               2ª Dose
# 26133727                   SP               1ª Dose

# %%
# Selecionando as pessoas vacinadas em SP e menor 12 anos
# e maior ou igual a 11 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 12) & (df.paciente_idade >= 11))]
# Out:
#          vacina_fabricante_nome  paciente_idade      vacina_dataAplicacao  \
# 245149                  Sinovac            11.0  2021-02-12T00:00:00.000Z
# 258539                  Sinovac            11.0  2021-02-11T00:00:00.000Z
# 353631                  Sinovac            11.0  2021-01-22T00:00:00.000Z
# 712219                  Sinovac            11.0  2021-01-21T00:00:00.000Z
# 1227613                 Sinovac            11.0  2021-02-15T00:00:00.000Z
# 1260105                 Sinovac            11.0  2021-02-05T00:00:00.000Z
# 1859798                 Sinovac            11.0  2021-01-22T00:00:00.000Z
# 3308497                 Sinovac            11.0  2021-02-19T00:00:00.000Z
# 3883511                 Sinovac            11.0  2021-01-29T00:00:00.000Z
# 4959715                 Sinovac            11.0  2021-01-26T00:00:00.000Z
# 4983081                 Sinovac            11.0  2021-02-10T00:00:00.000Z
# 7379970                 Sinovac            11.0  2021-03-17T00:00:00.000Z
# 8264698      AstraZeneca/Oxford            11.0  2021-01-29T00:00:00.000Z
# 8296836                 Sinovac            11.0  2021-02-26T00:00:00.000Z
# 9127275                 Sinovac            11.0  2021-01-23T00:00:00.000Z
# 10624729     AstraZeneca/Oxford            11.0  2021-01-29T00:00:00.000Z
# 10864157                Sinovac            11.0  2021-01-21T00:00:00.000Z
# 12798652                SINOVAC            11.0  2021-03-26T00:00:00.000Z
# 13586642                SINOVAC            11.0  2021-03-24T00:00:00.000Z
# 17287647     AstraZeneca/Oxford            11.0  2021-01-29T00:00:00.000Z
# 18539954                SINOVAC            11.0  2021-03-27T00:00:00.000Z
# 19706364                Sinovac            11.0  2021-02-25T00:00:00.000Z
# 20760191                Sinovac            11.0  2021-02-16T00:00:00.000Z
# 21616257                Sinovac            11.0  2021-03-08T00:00:00.000Z
# 22091517                SINOVAC            11.0  2021-04-01T00:00:00.000Z
# 22687250                Sinovac            11.0  2021-03-22T00:00:00.000Z
# 24872639                SINOVAC            11.0  2021-04-05T00:00:00.000Z
#
#          paciente_endereco_uf vacina_descricao_dose
# 245149                     SP               2ª Dose
# 258539                     SP               1ª Dose
# 353631                     SP               1ª Dose
# 712219                     SP               1ª Dose
# 1227613                    SP               2ª Dose
# 1260105                    SP               1ª Dose
# 1859798                    SP               1ª Dose
# 3308497                    SP               2ª Dose
# 3883511                    SP               1ª Dose
# 4959715                    SP               1ª Dose
# 4983081                    SP               2ª Dose
# 7379970                    SP               1ª Dose
# 8264698                    SP               1ª Dose
# 8296836                    SP               2ª Dose
# 9127275                    SP               1ª Dose
# 10624729                   SP               1ª Dose
# 10864157                   SP               1ª Dose
# 12798652                   SP               1ª Dose
# 13586642                   SP               1ª Dose
# 17287647                   SP               1ª Dose
# 18539954                   SP               1ª Dose
# 19706364                   SP               2ª Dose
# 20760191                   SP               1ª Dose
# 21616257                   SP               1ª Dose
# 22091517                   SP               1ª Dose
# 22687250                   SP               1ª Dose
# 24872639                   SP               2ª Dose

# %%
# Selecionando as pessoas vacinadas em SP e menor 11 anos
# e maior ou igual a 10 ano

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 11) & (df.paciente_idade >= 10))]
# Out:
#          vacina_fabricante_nome  paciente_idade      vacina_dataAplicacao  \
# 508030                  Sinovac            10.0  2021-01-26T00:00:00.000Z
# 815682                  Sinovac            10.0  2021-03-05T00:00:00.000Z
# 950613                  Sinovac            10.0  2021-03-02T00:00:00.000Z
# 1073056                 Sinovac            10.0  2021-02-16T00:00:00.000Z
# 1234910                 Sinovac            10.0  2021-02-02T00:00:00.000Z
# 1545309                 SINOVAC            10.0  2021-03-27T00:00:00.000Z
# 4112685                 Sinovac            10.0  2021-03-20T00:00:00.000Z
# 5704389       FUNDACAO BUTANTAN            10.0  2021-02-10T03:00:00.000Z
# 8909070                 Sinovac            10.0  2021-01-21T00:00:00.000Z
# 8923918      AstraZeneca/Oxford            10.0  2021-02-03T00:00:00.000Z
# 10334578                Sinovac            10.0  2021-02-12T00:00:00.000Z
# 10583885                Sinovac            10.0  2021-02-12T00:00:00.000Z
# 10586843                Sinovac            10.0  2021-01-29T00:00:00.000Z
# 10804037                Sinovac            10.0  2021-02-09T00:00:00.000Z
# 14906990                Sinovac            10.0  2021-02-17T00:00:00.000Z
# 14913998     AstraZeneca/Oxford            10.0  2021-02-04T00:00:00.000Z
# 15183255                Sinovac            10.0  2021-01-22T00:00:00.000Z
# 16746704                SINOVAC            10.0  2021-03-12T00:00:00.000Z
# 17231917                Sinovac            10.0  2021-03-03T00:00:00.000Z
# 17719825                Sinovac            10.0  2021-02-05T00:00:00.000Z
# 18339597                Sinovac            10.0  2021-02-15T00:00:00.000Z
# 19972281                Sinovac            10.0  2021-02-18T00:00:00.000Z
# 20439484                Sinovac            10.0  2021-01-27T00:00:00.000Z
# 21559923     AstraZeneca/Oxford            10.0  2021-02-01T00:00:00.000Z
# 21740682                Sinovac            10.0  2021-02-20T00:00:00.000Z
# 22052811                SINOVAC            10.0  2021-03-24T00:00:00.000Z
# 22169426                Sinovac            10.0  2021-01-30T00:00:00.000Z
# 25369256                SINOVAC            10.0  2021-03-27T00:00:00.000Z
#
#          paciente_endereco_uf vacina_descricao_dose
# 508030                     SP               1ª Dose
# 815682                     SP               2ª Dose
# 950613                     SP               2ª Dose
# 1073056                    SP               2ª Dose
# 1234910                    SP               1ª Dose
# 1545309                    SP               1ª Dose
# 4112685                    SP               1ª Dose
# 5704389                    SP               1ª Dose
# 8909070                    SP               1ª Dose
# 8923918                    SP               1ª Dose
# 10334578                   SP               1ª Dose
# 10583885                   SP               1ª Dose
# 10586843                   SP               1ª Dose
# 10804037                   SP               1ª Dose
# 14906990                   SP               2ª Dose
# 14913998                   SP               1ª Dose
# 15183255                   SP               1ª Dose
# 16746704                   SP               2ª Dose
# 17231917                   SP               1ª Dose
# 17719825                   SP               1ª Dose
# 18339597                   SP               2ª Dose
# 19972281                   SP               2ª Dose
# 20439484                   SP               1ª Dose
# 21559923                   SP               1ª Dose
# 21740682                   SP               2ª Dose
# 22052811                   SP               2ª Dose
# 22169426                   SP               1ª Dose
# 25369256                   SP               1ª Dose

# %%
# Selecionando as pessoas vacinadas em SP e menor 11 ano
# e maior ou igual 10 anos

df.loc[(df.paciente_endereco_uf == 'SP') & 
       ((df.paciente_idade < 11) & (df.paciente_idade >= 10))]
# Out:
#          vacina_fabricante_nome  paciente_idade      vacina_dataAplicacao  \
# 508030                  Sinovac            10.0  2021-01-26T00:00:00.000Z
# 815682                  Sinovac            10.0  2021-03-05T00:00:00.000Z
# 950613                  Sinovac            10.0  2021-03-02T00:00:00.000Z
# 1073056                 Sinovac            10.0  2021-02-16T00:00:00.000Z
# 1234910                 Sinovac            10.0  2021-02-02T00:00:00.000Z
# 1545309                 SINOVAC            10.0  2021-03-27T00:00:00.000Z
# 4112685                 Sinovac            10.0  2021-03-20T00:00:00.000Z
# 5704389       FUNDACAO BUTANTAN            10.0  2021-02-10T03:00:00.000Z
# 8909070                 Sinovac            10.0  2021-01-21T00:00:00.000Z
# 8923918      AstraZeneca/Oxford            10.0  2021-02-03T00:00:00.000Z
# 10334578                Sinovac            10.0  2021-02-12T00:00:00.000Z
# 10583885                Sinovac            10.0  2021-02-12T00:00:00.000Z
# 10586843                Sinovac            10.0  2021-01-29T00:00:00.000Z
# 10804037                Sinovac            10.0  2021-02-09T00:00:00.000Z
# 14906990                Sinovac            10.0  2021-02-17T00:00:00.000Z
# 14913998     AstraZeneca/Oxford            10.0  2021-02-04T00:00:00.000Z
# 15183255                Sinovac            10.0  2021-01-22T00:00:00.000Z
# 16746704                SINOVAC            10.0  2021-03-12T00:00:00.000Z
# 17231917                Sinovac            10.0  2021-03-03T00:00:00.000Z
# 17719825                Sinovac            10.0  2021-02-05T00:00:00.000Z
# 18339597                Sinovac            10.0  2021-02-15T00:00:00.000Z
# 19972281                Sinovac            10.0  2021-02-18T00:00:00.000Z
# 20439484                Sinovac            10.0  2021-01-27T00:00:00.000Z
# 21559923     AstraZeneca/Oxford            10.0  2021-02-01T00:00:00.000Z
# 21740682                Sinovac            10.0  2021-02-20T00:00:00.000Z
# 22052811                SINOVAC            10.0  2021-03-24T00:00:00.000Z
# 22169426                Sinovac            10.0  2021-01-30T00:00:00.000Z
# 25369256                SINOVAC            10.0  2021-03-27T00:00:00.000Z
#
#          paciente_endereco_uf vacina_descricao_dose
# 508030                     SP               1ª Dose
# 815682                     SP               2ª Dose
# 950613                     SP               2ª Dose
# 1073056                    SP               2ª Dose
# 1234910                    SP               1ª Dose
# 1545309                    SP               1ª Dose
# 4112685                    SP               1ª Dose
# 5704389                    SP               1ª Dose
# 8909070                    SP               1ª Dose
# 8923918                    SP               1ª Dose
# 10334578                   SP               1ª Dose
# 10583885                   SP               1ª Dose
# 10586843                   SP               1ª Dose
# 10804037                   SP               1ª Dose
# 14906990                   SP               2ª Dose
# 14913998                   SP               1ª Dose
# 15183255                   SP               1ª Dose
# 16746704                   SP               2ª Dose
# 17231917                   SP               1ª Dose
# 17719825                   SP               1ª Dose
# 18339597                   SP               2ª Dose
# 19972281                   SP               2ª Dose
# 20439484                   SP               1ª Dose
# 21559923                   SP               1ª Dose
# 21740682                   SP               2ª Dose
# 22052811                   SP               2ª Dose
# 22169426                   SP               1ª Dose
# 25369256                   SP               1ª Dose

# %% [markdown]
# # Total de Vacinados somente no Estado de São Paulo

# %%
# Out:
# Porcentagem dos Vacinados em SP: ==> 0.14660295493996425
